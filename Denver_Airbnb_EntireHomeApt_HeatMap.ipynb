# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap

# %%
# Importing listings CSV and storing it in a dataframe: den_data
all_den_data = pd.read_csv(r"C:\Users\bdmul\Documents\Coding applications\Python Projects\STRs\listings.csv")

# Viewing den_data dataframe
all_den_data
# Out:
#             id                                               name    host_id  \
# 0          177   Tiny Home in the Heart of the City- ECO FRIENDLY        615
# 1          360  Sit in the Peaceful Garden of the Chickadee Co...        666
# 2          364                Lodo / RiNo LOFT  via airport train        783
# 3          590                  Comfortable  - and a great value!        933
# 4          592                                            private        933
# ...        ...                                                ...        ...
# 3387  48877553                                         A blessing  219506731
# 3388  48885841                   Relax in comfort | 2BR in Denver  359071917
# 3389  48885842                Relax in comfort | Studio in Denver  359071917
# 3390  48888173  Live Lakeside in a Luxury Apartment | 2 BR in ...  359230893
# 3391  48922723                 Modern home in the heart of Denver   28873874
#
#                 host_name  neighbourhood_group                 neighbourhood  \
# 0                     Joe                  NaN              Virginia Village
# 1     Jennifer & Giovanni                  NaN                      Highland
# 2                   Jason                  NaN                   Five Points
# 3                    Jill                  NaN               North Park Hill
# 4                    Jill                  NaN               North Park Hill
# ...                   ...                  ...                           ...
# 3387            Victorien                  NaN  Gateway - Green Valley Ranch
# 3388                  Kia                  NaN                 West Highland
# 3389                  Kia                  NaN                 West Highland
# 3390              Carolyn                  NaN                   West Colfax
# 3391                 Nick                  NaN                City Park West
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 0     39.69551 -104.92489  Entire home/apt     85               1
# 1     39.76758 -105.00316  Entire home/apt    134               3
# 2     39.76672 -104.97906  Entire home/apt    179             185
# 3     39.75511 -104.91109     Private room     54               1
# 4     39.75481 -104.91106     Private room     45              29
# ...        ...        ...              ...    ...             ...
# 3387  39.77423 -104.76602     Private room     40               7
# 3388  39.76817 -105.03255  Entire home/apt    150              30
# 3389  39.76845 -105.03445  Entire home/apt    100              30
# 3390  39.74266 -105.04257  Entire home/apt    197              30
# 3391  39.74366 -104.96665  Entire home/apt    140              29
#
#       number_of_reviews last_review  reviews_per_month  \
# 0                    78  2020-12-31               1.40
# 1                   139  2021-02-28               4.34
# 2                    87  2016-04-26               0.60
# 3                   606  2020-09-01               4.14
# 4                   156  2020-11-08               1.06
# ...                 ...         ...                ...
# 3387                  0         NaN                NaN
# 3388                  0         NaN                NaN
# 3389                  0         NaN                NaN
# 3390                  0         NaN                NaN
# 3391                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 0                                  2               319
# 1                                  2                30
# 2                                  1               363
# 3                                  2                95
# 4                                  2               142
# ...                              ...               ...
# 3387                              16               365
# 3388                             142               301
# 3389                             142               293
# 3390                              21               360
# 3391                               1                59
#
# [3392 rows x 16 columns]

# %%
# Dropping unnessecary columns   
denver_data = all_den_data.drop(['neighbourhood_group', 'last_review', 'reviews_per_month', 'number_of_reviews', 'calculated_host_listings_count',
                   'availability_365', 'minimum_nights', 'host_name', 'host_id', 'name', 'id'], axis=1)

# setting index to 'neighbourhood'
#denver_data = denver_data.set_index('neighbourhood')
denver_data
# Out:
#                      neighbourhood  latitude  longitude        room_type  \
# 0                 Virginia Village  39.69551 -104.92489  Entire home/apt
# 1                         Highland  39.76758 -105.00316  Entire home/apt
# 2                      Five Points  39.76672 -104.97906  Entire home/apt
# 3                  North Park Hill  39.75511 -104.91109     Private room
# 4                  North Park Hill  39.75481 -104.91106     Private room
# ...                            ...       ...        ...              ...
# 3387  Gateway - Green Valley Ranch  39.77423 -104.76602     Private room
# 3388                 West Highland  39.76817 -105.03255  Entire home/apt
# 3389                 West Highland  39.76845 -105.03445  Entire home/apt
# 3390                   West Colfax  39.74266 -105.04257  Entire home/apt
# 3391                City Park West  39.74366 -104.96665  Entire home/apt
#
#       price
# 0        85
# 1       134
# 2       179
# 3        54
# 4        45
# ...     ...
# 3387     40
# 3388    150
# 3389    100
# 3390    197
# 3391    140
#
# [3392 rows x 5 columns]

# %%
# Splitting Entire home/apt into own dataframe
grouped = denver_data.groupby(denver_data.room_type)
entire_home_apt = grouped.get_group("Entire home/apt")
entire_home_apt
# Out:
#          neighbourhood  latitude  longitude        room_type  price
# 0     Virginia Village  39.69551 -104.92489  Entire home/apt     85
# 1             Highland  39.76758 -105.00316  Entire home/apt    134
# 2          Five Points  39.76672 -104.97906  Entire home/apt    179
# 6                Baker  39.72166 -104.99864  Entire home/apt     90
# 7        West Highland  39.76179 -105.02845  Entire home/apt     85
# ...                ...       ...        ...              ...    ...
# 3385               CBD  39.74465 -104.99511  Entire home/apt    159
# 3388     West Highland  39.76817 -105.03255  Entire home/apt    150
# 3389     West Highland  39.76845 -105.03445  Entire home/apt    100
# 3390       West Colfax  39.74266 -105.04257  Entire home/apt    197
# 3391    City Park West  39.74366 -104.96665  Entire home/apt    140
#
# [2741 rows x 5 columns]

# %%
hmap = folium.Map(location=[39.742043, -104.991531], zoom_start=11)

hm_wide = HeatMap(list(zip(entire_home_apt.latitude.values, entire_home_apt.longitude.values)),
                   min_opacity=0.2,
                   radius=17, blur=15, 
                   max_zoom=1)

hmap.add_child(hm_wide)

hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f17f4b37e3c545f79c6c7b454e907f90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f17f4b37e3c545f79c6c7b454e907f90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f17f4b37e3c545f79c6c7b454e907f90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f17f4b37e3c545f79c6c7b454e907f90%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
